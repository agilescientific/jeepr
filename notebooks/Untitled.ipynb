# %%
from jeep import Scan

# %%
s = Scan.from_rad('../tests/Multi-01_LINE00A.RA1')

# %%
s
# Out:
# Scan([[117, 117, 117, ..., -21, -21, -21],
#       [102, 102, 102, ..., -34, -34, -34],
#       [117, 117, 117, ..., -44, -44, -44],
#       ...,
#       [122, 122, 122, ...,  23,  23,  23],
#       [ 73,  73,  73, ...,  41,  41,  41],
#       [122, 122, 122, ...,  23,  23,  23]], dtype=int16)

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
plt.imshow(s.T)

# %%
s.shape
# Out:
# (233, 256)
